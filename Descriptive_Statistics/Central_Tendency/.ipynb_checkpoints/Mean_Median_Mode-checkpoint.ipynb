# %% [markdown]
# # Mean : $$ \overline x = \sum_{i=1}^n \frac{x_i }{n}   $$
#
#     - Central Value of the data
#     - Calculated by Sum of all data , divided by total number of data
#
# # Median :
#     - value separating the higher half from the lower half of a data
#
# # Mode :
#     - Most repeated value in the data

# %%
# %matplotlib inline


# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mode
import seaborn as sb

# %%
# Data 
Data = np.random.randint(low=10, high=100, size=100)
# print(Data)

mean = Data.mean()
median = np.median(Data)
mode_value = mode(Data)
# print("Mean : {}".format(mean))
# print("Median : {}".format(median))
# print("Mode : {}".format(mode_value))


#Histogram
plt.figure(figsize=(20, 10))
plt.hist(x=Data, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x=mean, linestyle='--', color = 'k')
plt.axvline(x=median, linestyle='--', color = 'c')
plt.axvline(x=mode_value.mode, linestyle='-.', color='g')

# Label and Titles

plt.xlabel('Data', size=20)
plt.ylabel('Count', size=20)
plt.title('Mean : {}, Median : {}, Mode : {}'.format(mean, median, mode_value), size=20)
plt.gca().legend((mean, median, mode_value))
sb.set_style('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1da6e88b2661> in <module>()
#      23 plt.ylabel('Count', size=20)
#      24 plt.title('Mean : {}, Median : {}, Mode : {}'.format(mean, median, mode_value), size=20)
# ---> 25 plt.gca().legend((mean, median, mode_value), size=20)
#      26 sb.set_style('whitegrid')
#
# c:\python35\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     563             raise TypeError('Invalid arguments to legend.')
#     564
# --> 565         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     566         self.legend_._remove_method = lambda h: setattr(self, 'legend_', None)
#     567         return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'size'
