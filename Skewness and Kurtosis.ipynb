# %% [markdown]
# # Skewness and Kurtosis :
# [Brown_Math_Explanation](https://brownmath.com/stat/shape.htm)
#
# [Skewness_Reduction_Technique_Kaggle](https://www.kaggle.com/gmailpawan/house-pricing-skew-reduction-technique)

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
from matplotlib import pyplot
from sklearn.datasets.samples_generator import make_blobs
from sklearn.datasets import samples_generator
from scipy.stats import skew, skewtest

# %%
X, y = make_blobs(n_samples=10000, n_features=4, center_box=(-10, 10))
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

# %%
df.plot(kind='scatter', x='x', y='y', c='label',colormap='viridis')

# %%
df.head()
# Out:
#    label         x         y
# 0      2 -6.917715  1.486290
# 1      2 -7.538669  3.717433
# 2      0 -5.666737  7.212367
# 3      2 -6.629919  3.175092
# 4      2 -6.923519  2.271077

# %%
df.plot(x='x', kind='hist')

# %%
df.plot(x='y', kind='hist')

# %%
df.plot(x='label', kind='hist')

# %%
skew(df['x'], axis=0)
# Out:
# 0.6162394795143229

# %%
skew(df['y'], axis=0)
# Out:
# -0.26240065948363245

# %%
skew(df['label'], axis=0)
# Out:
# 0.00018371632344472004

# %%
skewtest
